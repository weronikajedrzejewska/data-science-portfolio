# %% [markdown]
# ## Import libs

# %%
# %pip install datefinder
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datefinder
#   Downloading datefinder-0.7.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: regex>=2017.02.08 in /usr/local/lib/python3.7/dist-packages (from datefinder) (2019.12.20)
# Requirement already satisfied: python-dateutil>=2.4.2 in /usr/local/lib/python3.7/dist-packages (from datefinder) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from datefinder) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.4.2->datefinder) (1.15.0)
# Installing collected packages: datefinder
# Successfully installed datefinder-0.7.1

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import re
import datefinder

# %% [markdown]
# ## Load data from Wikipedia

# %%
website = requests.get("https://en.wikipedia.org/wiki/List_of_Olympic_medalists_in_athletics_(women)")

soup = bs(website.content)

html = soup.prettify();

# %% [markdown]
# ##  Fetch and clean data to store in Pandas DataFrame

# %%
final_rows = []
medalists_df = pd.DataFrame()
for index, value in enumerate(soup.select('h3')):
    table = value.find_next_sibling('table')
    tr_list = []
    if not table is None:
        '''
        Due to incoherent structures of tables,
        it is necessary to remove column names
        '''
        try:
            tr_list = table.find_all('tbody')[1].find_all('tr')
        except:
            tr_list = table.find_all('tbody')[0].find_all('tr')

    url = "https://en.wikipedia.org"
    row_list = []
    disc_column = value.get_text().replace('[edit]', '')

    '''
    Remove relay disciplines because this analysis aimed to individual records
    '''
    if 'relay' in disc_column:
        continue

    def has_numbers(input_string):
        input_string = input_string.find('a')
        if input_string is None:
            return False
        return any(char.isdigit() for char in input_string.get_text())

    def handle_blank(birthday):
        if not birthday:
            return 'No data'
        else:
            return birthday

    def has_vacants(entry):
        if 'Vacant' in entry.get_text():
            new_rows.append('none awarded')
            for i in range(2):
                new_rows.append('n/a')
            return True
    
    def has_non_awarded(entry):
        if not (entry.find('i') is None):
            new_rows.append('none awarded')
            return True

    def get_birthday(athlete):
        athlete = athlete.find('a')
        if not (athlete is None):
            if not (athlete.get('title') is None):
                if not (athlete.get_text()[0].isdigit()):
                    actual_url = url + athlete.get('href')
                    new_soup = requests.get(actual_url)
                    athlete_page = bs(new_soup.content)

                    '''
                    Cleaning out unneccessary html tags
                    '''
                    for tag in athlete_page.find_all(["sup", "span"]):
                        tag.decompose()
                    try:
                        '''
                        Date of birth is stored in the infobox on the right side of the page
                        '''
                        table_date = athlete_page.find('table', class_="infobox vcard").find('th', string='Born')
                        if not (table_date is None):
                            bday = table_date.find_next_sibling().get_text()
                            sep = '('
                            bday = bday.split(sep, 1)[0]
                            
                            '''
                            Wikipedia has a lot of incosistency between pages, thats why
                            external library is needed to commonize dates
                            '''
                            extracted = list(datefinder.find_dates(bday))
                            return extracted[0].strftime('%d-%m-%Y')
                    except:
                        return 'No data'


    for tr in tr_list:
        td = tr.find_all('td')

        entries = [e for e in td]

        '''
        To drop ex aequo medalists
        '''
        if len(entries) == 1:
            continue

        new_rows = [disc_column]
        for entry in entries:
            if has_vacants(entry) or has_non_awarded(entry):
                continue
            if not has_numbers(entry):
                '''
                To have seperate column for athlete name and her nationality
                '''
                splitted = entry.get_text().split("\xa0")
                new_rows.append(str(splitted[0]).strip())
                if len(splitted) > 1:
                    new_rows.append(str(splitted[1]).strip())
                else:
                    new_rows.append(entry.get_text)
                '''
                There is no date of birth in the main table so it is neccessary to
                open sub-webpage for each athlete and fetch it
                '''
                new_rows.append(handle_blank(get_birthday(entry)))
            elif str(entry.get_text())[0].isdigit():
                '''
                When column starts with digit it is always year of the games combined
                with city where it took place
                '''
                entry = str(entry.get_text())
                splitted = entry.split(' ', 1)
                new_rows.append(splitted[0])
                '''
                Neccessary cleaning of data
                '''
                new_rows.append(splitted[1].replace('details', '').strip())
            else:
                new_rows.append(entry.get_text())
        row_list.append(new_rows)
    '''
    Creating seperate DataFrame for each discipline and merging in each iteration
    '''
    df = pd.DataFrame(row_list)
    medalists_df = pd.concat([medalists_df, df])
    final_rows.append(row_list)
column_names = ['Discipline', 'Year of Games', 'Place of Games', 'Gold medalist', 'Country (Gold)',
                'Date of birth (Gold)', 'Silver medalist', 'Country (Silver)', 'Date of birth (Silver)',
                'Bronze medalist', 'Country (Bronze)', 'Date of birth (Bronze)']
medalists_df.columns = column_names

# %% [markdown]
# ## Additional cleaning of DataFrame

# %%
medalists_df = medalists_df[medalists_df['Country (Gold)'].str.contains('included')==False]
medalists_df.replace(to_replace=[None], value='n/a', inplace=True)
medalists_df.head(10)
# Out:
#    Discipline Year of Games Place of Games           Gold medalist  \
# 0  100 metres          1928      Amsterdam          Betty Robinson
# 1  100 metres          1932    Los Angeles  Stanisława Walasiewicz
# 2  100 metres          1936         Berlin          Helen Stephens
# 3  100 metres          1948         London     Fanny Blankers-Koen
# 4  100 metres          1952       Helsinki        Marjorie Jackson
# 5  100 metres          1956      Melbourne          Betty Cuthbert
# 6  100 metres          1960           Rome           Wilma Rudolph
# 7  100 metres          1964          Tokyo             Wyomia Tyus
# 8  100 metres          1968    Mexico City             Wyomia Tyus
# 9  100 metres          1972         Munich          Renate Stecher
#
#   Country (Gold) Date of birth (Gold)         Silver medalist  \
# 0  United States           23-08-1911         Fanny Rosenfeld
# 1         Poland           03-04-1911            Hilda Strike
# 2  United States           03-02-1918  Stanisława Walasiewicz
# 3    Netherlands           26-04-1918          Dorothy Manley
# 4      Australia           13-09-1931       Daphne Hasenjager
# 5      Australia           20-04-1938        Christa Stubnick
# 6  United States           23-06-1940           Dorothy Hyman
# 7  United States           29-08-1945           Edith McGuire
# 8  United States           29-08-1945         Barbara Ferrell
# 9   East Germany           12-05-1950           Raelene Boyle
#
#          Country (Silver) Date of birth (Silver)  \
# 0                  Canada             28-12-1904
# 1                  Canada             01-09-1910
# 2                  Poland             03-04-1911
# 3           Great Britain             29-04-1927
# 4            South Africa             02-07-1929
# 5  United Team of Germany             12-12-1933
# 6           Great Britain             09-05-1941
# 7           United States             03-06-1944
# 8           United States             28-07-1947
# 9               Australia             24-06-1951
#
#                   Bronze medalist Country (Bronze) Date of birth (Bronze)
# 0                     Ethel Smith           Canada             05-07-1907
# 1           Wilhelmina von Bremen    United States             13-08-1909
# 2                     Käthe Krauß          Germany             29-11-1906
# 3              Shirley Strickland        Australia             18-07-1925
# 4  Shirley Strickland de la Hunty        Australia             18-07-1925
# 5                Marlene Matthews        Australia             14-07-1934
# 6                Giuseppina Leone            Italy             21-12-1934
# 7                 Ewa Kłobukowska           Poland             01-10-1946
# 8                 Irena Szewińska           Poland             24-05-1946
# 9                   Silvia Chivás             Cuba             10-09-1954

# %% [markdown]
# ## Extend DataFrame with additional columns (age when awarded)

# %%
import numpy as np
import datetime
def extract_year(value):
    return int(value.split("-")[2].strip(" "))

medalists_df['Age (Gold)'] = medalists_df['Year of Games'].astype('int') - medalists_df['Date of birth (Gold)'].apply(lambda x: '0' if x == 'n/a' or x == 'No data' else f"{extract_year(x)}").astype('int')
medalists_df['Age (Silver)'] = medalists_df['Year of Games'].astype('int') - medalists_df['Date of birth (Silver)'].apply(lambda x: '0' if x == 'n/a' or x == 'No data' else f"{extract_year(x)}").astype('int')
medalists_df['Age (Bronze)'] = medalists_df['Year of Games'].astype('int') - medalists_df['Date of birth (Bronze)'].apply(lambda x: '0' if x == 'n/a' or x == 'No data' else f"{extract_year(x)}").astype('int')
medalists_df['Age (Gold)'] = medalists_df['Age (Gold)'].apply(lambda x: np.nan if x >1000 else x)
medalists_df['Age (Silver)'] = medalists_df['Age (Silver)'].apply(lambda x: np.nan if x >1000 else x)
medalists_df['Age (Bronze)'] = medalists_df['Age (Bronze)'].apply(lambda x: np.nan if x >1000 else x)
medalists_df = medalists_df[['Discipline', 'Year of Games', 'Place of Games', 'Gold medalist', 'Country (Gold)',
                'Date of birth (Gold)', 'Age (Gold)', 'Silver medalist', 'Country (Silver)', 'Date of birth (Silver)','Age (Silver)',
                'Bronze medalist', 'Country (Bronze)', 'Date of birth (Bronze)', 'Age (Bronze)']]
medalists_df.head(10)
# Out:
#    Discipline Year of Games Place of Games           Gold medalist  \
# 0  100 metres          1928      Amsterdam          Betty Robinson
# 1  100 metres          1932    Los Angeles  Stanisława Walasiewicz
# 2  100 metres          1936         Berlin          Helen Stephens
# 3  100 metres          1948         London     Fanny Blankers-Koen
# 4  100 metres          1952       Helsinki        Marjorie Jackson
# 5  100 metres          1956      Melbourne          Betty Cuthbert
# 6  100 metres          1960           Rome           Wilma Rudolph
# 7  100 metres          1964          Tokyo             Wyomia Tyus
# 8  100 metres          1968    Mexico City             Wyomia Tyus
# 9  100 metres          1972         Munich          Renate Stecher
#
#   Country (Gold) Date of birth (Gold)  Age (Gold)         Silver medalist  \
# 0  United States           23-08-1911        17.0         Fanny Rosenfeld
# 1         Poland           03-04-1911        21.0            Hilda Strike
# 2  United States           03-02-1918        18.0  Stanisława Walasiewicz
# 3    Netherlands           26-04-1918        30.0          Dorothy Manley
# 4      Australia           13-09-1931        21.0       Daphne Hasenjager
# 5      Australia           20-04-1938        18.0        Christa Stubnick
# 6  United States           23-06-1940        20.0           Dorothy Hyman
# 7  United States           29-08-1945        19.0           Edith McGuire
# 8  United States           29-08-1945        23.0         Barbara Ferrell
# 9   East Germany           12-05-1950        22.0           Raelene Boyle
#
#          Country (Silver) Date of birth (Silver)  Age (Silver)  \
# 0                  Canada             28-12-1904          24.0
# 1                  Canada             01-09-1910          22.0
# 2                  Poland             03-04-1911          25.0
# 3           Great Britain             29-04-1927          21.0
# 4            South Africa             02-07-1929          23.0
# 5  United Team of Germany             12-12-1933          23.0
# 6           Great Britain             09-05-1941          19.0
# 7           United States             03-06-1944          20.0
# 8           United States             28-07-1947          21.0
# 9               Australia             24-06-1951          21.0
#
#                   Bronze medalist Country (Bronze) Date of birth (Bronze)  \
# 0                     Ethel Smith           Canada             05-07-1907
# 1           Wilhelmina von Bremen    United States             13-08-1909
# 2                     Käthe Krauß          Germany             29-11-1906
# 3              Shirley Strickland        Australia             18-07-1925
# 4  Shirley Strickland de la Hunty        Australia             18-07-1925
# 5                Marlene Matthews        Australia             14-07-1934
# 6                Giuseppina Leone            Italy             21-12-1934
# 7                 Ewa Kłobukowska           Poland             01-10-1946
# 8                 Irena Szewińska           Poland             24-05-1946
# 9                   Silvia Chivás             Cuba             10-09-1954
#
#    Age (Bronze)
# 0          21.0
# 1          23.0
# 2          30.0
# 3          23.0
# 4          27.0
# 5          22.0
# 6          26.0
# 7          18.0
# 8          22.0
# 9          18.0

# %% [markdown]
# ## Export to csv

# %%
medalists_df.to_csv('medalists.csv', index=False)

# %% [markdown]
# ## Export to json

# %%
import json
medalists = medalists_df.to_json(orient='split')
parsed = json.loads(medalists)
json.dumps(parsed, indent=4);

# %% [markdown]
# ## Store data in Postgresql

# %%
# %pip install sqlalchemy
# %pip install psycopg2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (1.4.36)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy) (1.1.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy) (3.8.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: psycopg2 in /usr/local/lib/python3.7/dist-packages (2.7.6.1)

# %%
import psycopg2
from sqlalchemy import create_engine
  
  
conn_string = '****************'
  
db = create_engine(conn_string)
conn = db.connect()

medalists_df.to_sql('data', con=conn, if_exists='replace', index=False, method='multi')

conn = psycopg2.connect(conn_string)
conn.autocommit = True
cursor = conn.cursor()
  
sql1 = '''select * from data;'''
cursor.execute(sql1)
for i in cursor.fetchall():
    print(i)
  
conn.close()
# Out:
# ('100 metres', '1928', 'Amsterdam', 'Betty Robinson', 'United States', '23-08-1911', 17.0, 'Fanny Rosenfeld', 'Canada', '28-12-1904', 24.0, 'Ethel Smith', 'Canada', '05-07-1907', 21.0)
# ('100 metres', '1932', 'Los Angeles', 'Stanisława Walasiewicz', 'Poland', '03-04-1911', 21.0, 'Hilda Strike', 'Canada', '01-09-1910', 22.0, 'Wilhelmina von Bremen', 'United States', '13-08-1909', 23.0)
# ('100 metres', '1936', 'Berlin', 'Helen Stephens', 'United States', '03-02-1918', 18.0, 'Stanisława Walasiewicz', 'Poland', '03-04-1911', 25.0, 'Käthe Krauß', 'Germany', '29-11-1906', 30.0)
# ('100 metres', '1948', 'London', 'Fanny Blankers-Koen', 'Netherlands', '26-04-1918', 30.0, 'Dorothy Manley', 'Great Britain', '29-04-1927', 21.0, 'Shirley Strickland', 'Australia', '18-07-1925', 23.0)
# ('100 metres', '1952', 'Helsinki', 'Marjorie Jackson', 'Australia', '13-09-1931', 21.0, 'Daphne Hasenjager', 'South Africa', '02-07-1929', 23.0, 'Shirley Strickland de la Hunty', 'Australia', '18-07-1925', 27.0)
# ('100 metres', '1956', 'Melbourne', 'Betty Cuthbert', 'Australia', '20-04-1938', 18.0, 'Christa Stubnick', 'United Team of Germany', '12-12-1933', 23.0, 'Marlene Matthews', 'Australia', '14-07-1934', 22.0)
# ('100 metres', '1960', 'Rome', 'Wilma Rudolph', 'United States', '23-06-1940', 20.0, 'Dorothy Hyman', 'Great Britain', '09-05-1941', 19.0, 'Giuseppina Leone', 'Italy', '21-12-1934', 26.0)
# ('100 metres', '1964', 'Tokyo', 'Wyomia Tyus', 'United States', '29-08-1945', 19.0, 'Edith McGuire', 'United States', '03-06-1944', 20.0, 'Ewa Kłobukowska', 'Poland', '01-10-1946', 18.0)
# ('100 metres', '1968', 'Mexico City', 'Wyomia Tyus', 'United States', '29-08-1945', 23.0, 'Barbara Ferrell', 'United States', '28-07-1947', 21.0, 'Irena Szewińska', 'Poland', '24-05-1946', 22.0)
# ('100 metres', '1972', 'Munich', 'Renate Stecher', 'East Germany', '12-05-1950', 22.0, 'Raelene Boyle', 'Australia', '24-06-1951', 21.0, 'Silvia Chivás', 'Cuba', '10-09-1954', 18.0)
# ('100 metres', '1976', 'Montreal', 'Annegret Richter', 'West Germany', '13-10-1950', 26.0, 'Renate Stecher', 'East Germany', '12-05-1950', 26.0, 'Inge Helten', 'West Germany', '31-12-1950', 26.0)
# ('100 metres', '1980', 'Moscow', 'Lyudmila Kondratyeva', 'Soviet Union', '11-04-1958', 22.0, 'Marlies Göhr', 'East Germany', '21-03-1958', 22.0, 'Ingrid Auerswald', 'East Germany', 'No data', None)
# ('100 metres', '1984', 'Los Angeles', 'Evelyn Ashford', 'United States', '15-04-1957', 27.0, 'Alice Brown', 'United States', '20-09-1960', 24.0, 'Merlene Ottey', 'Jamaica', '10-05-1960', 24.0)
# ('100 metres', '1988', 'Seoul', 'Florence Griffith-Joyner', 'United States', '21-12-1959', 29.0, 'Evelyn Ashford', 'United States', '15-04-1957', 31.0, 'Heike Drechsler', 'East Germany', '16-12-1964', 24.0)
# ('100 metres', '1992', 'Barcelona', 'Gail Devers', 'United States', '19-11-1966', 26.0, 'Juliet Cuthbert', 'Jamaica', '09-04-1964', 28.0, 'Irina Privalova', 'Unified Team', '22-11-1968', 24.0)
# ('100 metres', '1996', 'Atlanta', 'Gail Devers', 'United States', '19-11-1966', 30.0, 'Merlene Ottey', 'Jamaica', '10-05-1960', 36.0, 'Gwen Torrence', 'United States', '12-06-1965', 31.0)
# ('100 metres', '2000', 'Sydney', 'none awarded', 'n/a', 'n/a', None, 'Ekaterini Thanou', 'Greece', '01-02-1975', 25.0, 'Merlene Ottey', 'Jamaica', '10-05-1960', 40.0)
# ('100 metres', '2004', 'Athens', 'Yulia Nestsiarenka', 'Belarus', '15-06-1979', 25.0, 'Lauryn Williams', 'United States', 'No data', None, 'Veronica Campbell', 'Jamaica', '15-05-1982', 22.0)
# ('100 metres', '2008', 'Beijing', 'Shelly-Ann Fraser', 'Jamaica', '27-12-1986', 22.0, 'Sherone Simpson', 'Jamaica', '12-08-1984', 24.0, 'none awarded', 'n/a', 'n/a', None)
# ('100 metres', '2012', 'London', 'Shelly-Ann Fraser-Pryce', 'Jamaica', '27-12-1986', 26.0, 'Carmelita Jeter', 'United States', '24-11-1979', 33.0, 'Veronica Campbell-Brown', 'Jamaica', '15-05-1982', 30.0)
# ('100 metres', '2016', 'Rio de Janeiro', 'Elaine Thompson', 'Jamaica', '28-06-1992', 24.0, 'Tori Bowie', 'United States', '27-08-1990', 26.0, 'Shelly-Ann Fraser-Pryce', 'Jamaica', '27-12-1986', 30.0)
# ('100 metres', '2020', 'Tokyo', 'Elaine Thompson-Herah', 'Jamaica', '28-06-1992', 28.0, 'Shelly-Ann Fraser-Pryce', 'Jamaica', '27-12-1986', 34.0, 'Shericka Jackson', 'Jamaica', '16-07-1994', 26.0)
# ('200 metres', '1948', 'London', 'Fanny Blankers-Koen', 'Netherlands', '26-04-1918', 30.0, 'Audrey Williamson', 'Great Britain', 'No data', None, 'Audrey Patterson', 'United States', 'No data', None)
# ('200 metres', '1952', 'Helsinki', 'Marjorie Jackson', 'Australia', '13-09-1931', 21.0, 'Bertha Brouwer', 'Netherlands', '29-10-1930', 22.0, 'Nadezhda Khnykina-Dvalishvili', 'Soviet Union', 'No data', None)
# ('200 metres', '1956', 'Melbourne', 'Betty Cuthbert', 'Australia', '20-04-1938', 18.0, 'Christa Stubnick', 'United Team of Germany', '12-12-1933', 23.0, 'Marlene Mathews', 'Australia', '14-07-1934', 22.0)
# ('200 metres', '1960', 'Rome', 'Wilma Rudolph', 'United States', '23-06-1940', 20.0, 'Jutta Heine', 'United Team of Germany', '16-09-1940', 20.0, 'Dorothy Hyman', 'Great Britain', '09-05-1941', 19.0)
# ('200 metres', '1964', 'Tokyo', 'Edith McGuire', 'United States', '03-06-1944', 20.0, 'Irena Kirszenstein', 'Poland', '24-05-1946', 18.0, 'Marilyn Black', 'Australia', 'No data', None)
# ('200 metres', '1968', 'Mexico City', 'Irena Szewińska', 'Poland', '24-05-1946', 22.0, 'Raelene Boyle', 'Australia', '24-06-1951', 17.0, 'Jenny Lamy', 'Australia', 'No data', None)
# ('200 metres', '1972', 'Munich', 'Renate Stecher', 'East Germany', '12-05-1950', 22.0, 'Raelene Boyle', 'Australia', '24-06-1951', 21.0, 'Irena Szewińska', 'Poland', '24-05-1946', 26.0)
# ('200 metres', '1976', 'Montreal', 'Bärbel Eckert', 'East Germany', 'No data', None, 'Annegret Richter', 'West Germany', '13-10-1950', 26.0, 'Renate Stecher', 'East Germany', '12-05-1950', 26.0)
# ('200 metres', '1980', 'Moscow', 'Bärbel Wöckel', 'East Germany', 'No data', None, 'Natalya Bochina', 'Soviet Union', '04-01-1962', 18.0, 'Merlene Ottey', 'Jamaica', '10-05-1960', 20.0)
# ('200 metres', '1984', 'Los Angeles', 'Valerie Brisco-Hooks', 'United States', '06-07-1960', 24.0, 'Florence Griffith', 'United States', '21-12-1959', 25.0, 'Merlene Ottey', 'Jamaica', '10-05-1960', 24.0)
# ('200 metres', '1988', 'Seoul', 'Florence Griffith-Joyner', 'United States', '21-12-1959', 29.0, 'Grace Jackson', 'Jamaica', 'No data', None, 'Heike Drechsler', 'East Germany', '16-12-1964', 24.0)
# ('200 metres', '1992', 'Barcelona', 'Gwen Torrence', 'United States', '12-06-1965', 27.0, 'Juliet Cuthbert', 'Jamaica', '09-04-1964', 28.0, 'Merlene Ottey', 'Jamaica', '10-05-1960', 32.0)
# ('200 metres', '1996', 'Atlanta', 'Marie-José Pérec', 'France', '09-05-1968', 28.0, 'Merlene Ottey', 'Jamaica', '10-05-1960', 36.0, 'Mary Onyali', 'Nigeria', '03-02-1968', 28.0)
# ('200 metres', '2000', 'Sydney', 'Pauline Davis-Thompson', 'Bahamas', '09-07-1966', 34.0, 'Susanthika Jayasinghe', 'Sri Lanka', '17-12-1975', 25.0, 'Beverly McDonald', 'Jamaica', 'No data', None)
# ('200 metres', '2004', 'Athens', 'Veronica Campbell', 'Jamaica', '15-05-1982', 22.0, 'Allyson Felix', 'United States', '18-11-1985', 19.0, 'Debbie Ferguson', 'Bahamas', 'No data', None)
# ('200 metres', '2008', 'Beijing', 'Veronica Campbell-Brown', 'Jamaica', '15-05-1982', 26.0, 'Allyson Felix', 'United States', '18-11-1985', 23.0, 'Kerron Stewart', 'Jamaica', 'No data', None)
# ('200 metres', '2012', 'London', 'Allyson Felix', 'United States', '18-11-1985', 27.0, 'Shelly-Ann Fraser-Pryce', 'Jamaica', '27-12-1986', 26.0, 'Carmelita Jeter', 'United States', '24-11-1979', 33.0)
# ('200 metres', '2016', 'Rio de Janeiro', 'Elaine Thompson', 'Jamaica', '28-06-1992', 24.0, 'Dafne Schippers', 'Netherlands', '15-06-1992', 24.0, 'Tori Bowie', 'United States', '27-08-1990', 26.0)
# ('200 metres', '2020', 'Tokyo', 'Elaine Thompson-Herah', 'Jamaica', '28-06-1992', 28.0, 'Christine Mboma', 'Namibia', '22-05-2003', 17.0, 'Gabrielle Thomas', 'United States', '07-12-1996', 24.0)
# ('400 metres', '1964', 'Tokyo', 'Betty Cuthbert', 'Australia', '20-04-1938', 26.0, 'Ann Packer', 'Great Britain', '08-03-1942', 22.0, 'Judy Amoore', 'Australia', '25-06-1940', 24.0)
# ('400 metres', '1968', 'Mexico City', 'Colette Besson', 'France', '07-04-1946', 22.0, 'Lillian Board', 'Great Britain', '13-12-1948', 20.0, 'Natalya Pechonkina', 'Soviet Union', 'No data', None)
# ('400 metres', '1972', 'Munich', 'Monika Zehrt', 'East Germany', '29-09-1952', 20.0, 'Rita Wilden', 'West Germany', '09-10-1947', 25.0, 'Kathy Hammond', 'United States', '02-11-1951', 21.0)
# ('400 metres', '1976', 'Montreal', 'Irena Szewińska', 'Poland', '24-05-1946', 30.0, 'Christina Brehmer', 'East Germany', '28-02-1958', 18.0, 'Ellen Streidt', 'East Germany', 'No data', None)
# ('400 metres', '1980', 'Moscow', 'Marita Koch', 'East Germany', '18-02-1957', 23.0, 'Jarmila Kratochvílová', 'Czechoslovakia', 'No data', None, 'Christina Lathan', 'East Germany', '28-02-1958', 22.0)
# ('400 metres', '1984', 'Los Angeles', 'Valerie Brisco-Hooks', 'United States', '06-07-1960', 24.0, 'Chandra Cheeseborough', 'United States', '10-01-1959', 25.0, 'Kathy Smallwood-Cook', 'Great Britain', 'No data', None)
# ('400 metres', '1988', 'Seoul', 'Olga Bryzgina', 'Soviet Union', '30-06-1963', 25.0, 'Petra Müller', 'East Germany', 'No data', None, 'Olga Nazarova', 'Soviet Union', 'No data', None)
# ('400 metres', '1992', 'Barcelona', 'Marie-José Pérec', 'France', '09-05-1968', 24.0, 'Olga Bryzgina', 'Unified Team', '30-06-1963', 29.0, 'Ximena Restrepo', 'Colombia', '10-03-1969', 23.0)
# ('400 metres', '1996', 'Atlanta', 'Marie-José Pérec', 'France', '09-05-1968', 28.0, 'Cathy Freeman', 'Australia', '16-02-1973', 23.0, 'Falilat Ogunkoya', 'Nigeria', '05-12-1968', 28.0)
# ('400 metres', '2000', 'Sydney', 'Cathy Freeman', 'Australia', '16-02-1973', 27.0, 'Lorraine Graham', 'Jamaica', '08-09-1973', 27.0, 'Katharine Merry', 'Great Britain', '21-09-1974', 26.0)
# ('400 metres', '2004', 'Athens', 'Tonique Williams-Darling', 'Bahamas', 'No data', None, 'Ana Guevara', 'Mexico', '04-03-1977', 27.0, 'Natalya Antyukh', 'Russia', '26-06-1981', 23.0)
# ('400 metres', '2008', 'Beijing', 'Christine Ohuruogu', 'Great Britain', '17-05-1984', 24.0, 'Shericka Williams', 'Jamaica', '17-09-1985', 23.0, 'Sanya Richards', 'United States', '26-02-1985', 23.0)
# ('400 metres', '2012', 'London', 'Sanya Richards-Ross', 'United States', '26-02-1985', 27.0, 'Christine Ohuruogu', 'Great Britain', '17-05-1984', 28.0, 'DeeDee Trotter', 'United States', '08-12-1982', 30.0)
# ('400 metres', '2016', 'Rio de Janeiro', 'Shaunae Miller', 'Bahamas', '15-04-1994', 22.0, 'Allyson Felix', 'United States', '18-11-1985', 31.0, 'Shericka Jackson', 'Jamaica', '16-07-1994', 22.0)
# ('400 metres', '2020', 'Tokyo', 'Shaunae Miller-Uibo', 'Bahamas', '15-04-1994', 26.0, 'Marileidy Paulino', 'Dominican Republic', '25-10-1996', 24.0, 'Allyson Felix', 'United States', '18-11-1985', 35.0)
# ('800 metres', '1928', 'Amsterdam', 'Lina Radke', 'Germany', '18-10-1903', 25.0, 'Kinuye Hitomi', 'Japan', '01-01-1907', 21.0, 'Inga Gentzel', 'Sweden', '24-04-1908', 20.0)
# ('800 metres', '1960', 'Rome', 'Lyudmila Shevtsova', 'Soviet Union', '26-11-1934', 26.0, 'Brenda Jones', 'Australia', '17-11-1936', 24.0, 'Ursula Donath', 'United Team of Germany', 'No data', None)
# ('800 metres', '1964', 'Tokyo', 'Ann Packer', 'Great Britain', '08-03-1942', 22.0, 'Maryvonne Dupureur', 'France', '24-05-1937', 27.0, 'Marise Chamberlain', 'New Zealand', '05-12-1935', 29.0)
# ('800 metres', '1968', 'Mexico City', 'Madeline Manning', 'United States', '11-01-1948', 20.0, 'Ilona Silai', 'Romania', '14-10-1941', 27.0, 'Mia Gommers', 'Netherlands', '26-09-1939', 29.0)
# ('800 metres', '1972', 'Munich', 'Hildegard Falck', 'West Germany', '08-06-1949', 23.0, 'Nijolė Sabaitė', 'Soviet Union', 'No data', None, 'Gunhild Hoffmeister', 'East Germany', '06-07-1944', 28.0)
# ('800 metres', '1976', 'Montreal', 'Tatyana Kazankina', 'Soviet Union', 'No data', None, 'Nikolina Shtereva', 'Bulgaria', 'No data', None, 'Elfi Zinn', 'East Germany', 'No data', None)
# ('800 metres', '1980', 'Moscow', 'Nadiya Olizarenko', 'Soviet Union', '28-11-1953', 27.0, 'Olga Mineyeva', 'Soviet Union', '01-09-1952', 28.0, 'Tatyana Providokhina', 'Soviet Union', '26-03-1953', 27.0)
# ('800 metres', '1984', 'Los Angeles', 'Doina Melinte', 'Romania', '27-12-1956', 28.0, 'Kim Gallagher', 'United States', '11-06-1964', 20.0, 'Fiţa Lovin', 'Romania', '14-01-1951', 33.0)
# ('800 metres', '1988', 'Seoul', 'Sigrun Wodars', 'East Germany', 'No data', None, 'Christine Wachtel', 'East Germany', 'No data', None, 'Kim Gallagher', 'United States', '11-06-1964', 24.0)
# ('800 metres', '1992', 'Barcelona', 'Ellen van Langen', 'Netherlands', '09-02-1966', 26.0, 'Liliya Nurutdinova', 'Unified Team', 'No data', None, 'Ana Fidelia Quirot', 'Cuba', '23-03-1963', 29.0)
# ('800 metres', '1996', 'Atlanta', 'Svetlana Masterkova', 'Russia', '17-01-1968', 28.0, 'Ana Fidelia Quirot', 'Cuba', '23-03-1963', 33.0, 'Maria Mutola', 'Mozambique', '27-10-1972', 24.0)
# ('800 metres', '2000', 'Sydney', 'Maria Mutola', 'Mozambique', '27-10-1972', 28.0, 'Stephanie Graf', 'Austria', 'No data', None, 'Kelly Holmes', 'Great Britain', '19-04-1970', 30.0)
# ('800 metres', '2004', 'Athens', 'Kelly Holmes', 'Great Britain', '19-04-1970', 34.0, 'Hasna Benhassi', 'Morocco', '01-06-1978', 26.0, 'Jolanda Čeplak', 'Slovenia', 'No data', None)
# ('800 metres', '2008', 'Beijing', 'Pamela Jelimo', 'Kenya', '05-12-1989', 19.0, 'Janeth Jepkosgei', 'Kenya', '13-12-1983', 25.0, 'Hasna Benhassi', 'Morocco', '01-06-1978', 30.0)
# ('800 metres', '2012', 'London', 'Caster Semenya', 'South Africa[2]', '07-01-1991', 21.0, 'Ekaterina Poistogova', 'Russia', '01-03-1991', 21.0, 'Pamela Jelimo', 'Kenya', '05-12-1989', 23.0)
# ('800 metres', '2016', 'Rio de Janeiro', 'Caster Semenya', 'South Africa', '07-01-1991', 25.0, 'Francine Niyonsaba', 'Burundi', '05-05-1993', 23.0, 'Margaret Wambui', 'Kenya', '15-09-1995', 21.0)
# ('800 metres', '2020', 'Tokyo', 'Athing Mu', 'United States', '08-06-2002', 18.0, 'Keely Hodgkinson', 'Great Britain', '03-03-2002', 18.0, 'Raevyn Rogers', 'United States', '07-09-1996', 24.0)
# ('1500 metres', '1972', 'Munich', 'Lyudmila Bragina', 'Soviet Union', '24-07-1943', 29.0, 'Gunhild Hoffmeister', 'East Germany', '06-07-1944', 28.0, 'Paola Pigni', 'Italy', '30-12-1945', 27.0)
# ('1500 metres', '1976', 'Montreal', 'Tatyana Kazankina', 'Soviet Union', 'No data', None, 'Gunhild Hoffmeister', 'East Germany', '06-07-1944', 32.0, 'Ulrike Klapezynski', 'East Germany', 'No data', None)
# ('1500 metres', '1980', 'Moscow', 'Tatyana Kazankina', 'Soviet Union', 'No data', None, 'Christiane Wartenberg', 'East Germany', 'No data', None, 'Nadiya Olizarenko', 'Soviet Union', '28-11-1953', 27.0)
# ('1500 metres', '1984', 'Los Angeles', 'Gabriella Dorio', 'Italy', '27-06-1957', 27.0, 'Doina Melinte', 'Romania', '27-12-1956', 28.0, 'Maricica Puică', 'Romania', '29-07-1950', 34.0)
# ('1500 metres', '1988', 'Seoul', 'Paula Ivan', 'Romania', '20-07-1963', 25.0, 'Laimutė Baikauskaitė', 'Soviet Union', 'No data', None, 'Tetyana Samolenko', 'Soviet Union', '12-08-1961', 27.0)
# ('1500 metres', '1992', 'Barcelona', 'Hassiba Boulmerka', 'Algeria', 'No data', None, 'Lyudmila Rogachova', 'Unified Team', 'No data', None, 'Qu Yunxia', 'China', '25-12-1972', 20.0)
# ('1500 metres', '1996', 'Atlanta', 'Svetlana Masterkova', 'Russia', '17-01-1968', 28.0, 'Gabriela Szabo', 'Romania', '14-11-1975', 21.0, 'Theresia Kiesl', 'Austria', 'No data', None)
# ('1500 metres', '2000', 'Sydney', 'Nouria Mérah-Benida', 'Algeria', '19-10-1970', 30.0, 'Violeta Szekely', 'Romania', 'No data', None, 'Gabriela Szabo', 'Romania', '14-11-1975', 25.0)
# ('1500 metres', '2004', 'Athens', 'Kelly Holmes', 'Great Britain', '19-04-1970', 34.0, 'Tatyana Tomashova', 'Russia', 'No data', None, 'Maria Cioncan', 'Romania', 'No data', None)
# ('1500 metres', '2008', 'Beijing', 'Nancy Langat', 'Kenya', '22-08-1981', 27.0, 'Iryna Lishchynska', 'Ukraine', 'No data', None, 'Nataliya Tobias', 'Ukraine', 'No data', None)
# ('1500 metres', '2012', 'London', 'Maryam Yusuf Jamal', 'Bahrain[3]', 'No data', None, 'Tatyana Tomashova', 'Russia', 'No data', None, 'Abeba Aregawi', 'Ethiopia', '05-07-1990', 22.0)
# ('1500 metres', '2016', 'Rio de Janeiro', 'Faith Kipyegon', 'Kenya', '10-01-1994', 22.0, 'Genzebe Dibaba', 'Ethiopia', '08-02-1991', 25.0, 'Jennifer Simpson', 'United States', '23-08-1986', 30.0)
# ('1500 metres', '2020', 'Tokyo', 'Faith Kipyegon', 'Kenya', '10-01-1994', 26.0, 'Laura Muir', 'Great Britain', '09-05-1993', 27.0, 'Sifan Hassan', 'Netherlands', '01-01-1993', 27.0)
# ('5000 metres', '1996', 'Atlanta', 'Wang Junxia', 'China', '19-01-1973', 23.0, 'Pauline Konga', 'Kenya', 'No data', None, 'Roberta Brunet', 'Italy', '20-05-1965', 31.0)
# ('5000 metres', '2000', 'Sydney', 'Gabriela Szabo', 'Romania', '14-11-1975', 25.0, "Sonia O'Sullivan", 'Ireland', '28-11-1969', 31.0, 'Gete Wami', 'Ethiopia', 'No data', None)
# ('5000 metres', '2004', 'Athens', 'Meseret Defar', 'Ethiopia', '19-11-1983', 21.0, 'Isabella Ochichi', 'Kenya', 'No data', None, 'Tirunesh Dibaba', 'Ethiopia', '01-06-1985', 19.0)
# ('5000 metres', '2008', 'Beijing', 'Tirunesh Dibaba', 'Ethiopia', '01-06-1985', 23.0, 'Meseret Defar', 'Ethiopia', '19-11-1983', 25.0, 'Sylvia Kibet', 'Kenya', 'No data', None)
# ('5000 metres', '2012', 'London', 'Meseret Defar', 'Ethiopia', '19-11-1983', 29.0, 'Vivian Cheruiyot', 'Kenya', '11-09-1983', 29.0, 'Tirunesh Dibaba', 'Ethiopia', '01-06-1985', 27.0)
# ('5000 metres', '2016', 'Rio de Janeiro', 'Vivian Cheruiyot', 'Kenya', '11-09-1983', 33.0, 'Hellen Obiri', 'Kenya', '13-12-1989', 27.0, 'Almaz Ayana', 'Ethiopia', '21-11-1991', 25.0)
# ('5000 metres', '2020', 'Tokyo', 'Sifan Hassan', 'Netherlands', '01-01-1993', 27.0, 'Hellen Obiri', 'Kenya', '13-12-1989', 31.0, 'Gudaf Tsegay', 'Ethiopia', '23-01-1997', 23.0)
# ('10,000 metres', '1988', 'Seoul', 'Olga Bondarenko', 'Soviet Union', 'No data', None, 'Liz McColgan', 'Great Britain', '24-05-1964', 24.0, 'Yelena Zhupiyeva-Vyazova', 'Soviet Union', 'No data', None)
# ('10,000 metres', '1992', 'Barcelona', 'Derartu Tulu', 'Ethiopia', '21-03-1972', 20.0, 'Elana Meyer', 'South Africa', 'No data', None, 'Lynn Jennings', 'United States', '01-07-1960', 32.0)
# ('10,000 metres', '1996', 'Atlanta', 'Fernanda Ribeiro', 'Portugal', '23-06-1969', 27.0, 'Wang Junxia', 'China', '19-01-1973', 23.0, 'Gete Wami', 'Ethiopia', 'No data', None)
# ('10,000 metres', '2000', 'Sydney', 'Derartu Tulu', 'Ethiopia', '21-03-1972', 28.0, 'Gete Wami', 'Ethiopia', 'No data', None, 'Fernanda Ribeiro', 'Portugal', '23-06-1969', 31.0)
# ('10,000 metres', '2004', 'Athens', 'Xing Huina', 'China', 'No data', None, 'Ejagayehu Dibaba', 'Ethiopia', 'No data', None, 'Derartu Tulu', 'Ethiopia', '21-03-1972', 32.0)
# ('10,000 metres', '2008', 'Beijing', 'Tirunesh Dibaba', 'Ethiopia', '01-06-1985', 23.0, 'Shalane Flanagan', 'United States', '08-07-1981', 27.0, 'Linet Chepkwemoi Masai', 'Kenya', '05-12-1989', 19.0)
# ('10,000 metres', '2012', 'London', 'Tirunesh Dibaba', 'Ethiopia', '01-06-1985', 27.0, 'Sally Kipyego', 'Kenya', '19-12-1985', 27.0, 'Vivian Cheruiyot', 'Kenya', '11-09-1983', 29.0)
# ('10,000 metres', '2016', 'Rio de Janeiro', 'Almaz Ayana', 'Ethiopia', '21-11-1991', 25.0, 'Vivian Cheruiyot', 'Kenya', '11-09-1983', 33.0, 'Tirunesh Dibaba', 'Ethiopia', '01-06-1985', 31.0)
# ('10,000 metres', '2020', 'Tokyo', 'Sifan Hassan', 'Netherlands', '01-01-1993', 27.0, 'Kalkidan Gezahegne', 'Bahrain', '08-05-1991', 29.0, 'Letesenbet Gidey', 'Ethiopia', '20-03-1998', 22.0)
# ('Marathon', '1984', 'Los Angeles', 'Joan Benoit', 'United States', '16-05-1957', 27.0, 'Grete Waitz', 'Norway', '01-10-1953', 31.0, 'Rosa Mota', 'Portugal', '29-06-1958', 26.0)
# ('Marathon', '1988', 'Seoul', 'Rosa Mota', 'Portugal', '29-06-1958', 30.0, 'Lisa Martin', 'Australia', '12-05-1960', 28.0, 'Katrin Dörre', 'East Germany', 'No data', None)
# ('Marathon', '1992', 'Barcelona', 'Valentina Yegorova', 'Unified Team', 'No data', None, 'Yuko Arimori', 'Japan', '17-12-1966', 26.0, 'Lorraine Moller', 'New Zealand', '01-06-1955', 37.0)
# ('Marathon', '1996', 'Atlanta', 'Fatuma Roba', 'Ethiopia', '18-12-1973', 23.0, 'Valentina Yegorova', 'Russia', 'No data', None, 'Yuko Arimori', 'Japan', '17-12-1966', 30.0)
# ('Marathon', '2000', 'Sydney', 'Naoko Takahashi', 'Japan', 'No data', None, 'Lidia Șimon', 'Romania', '04-09-1973', 27.0, 'Joyce Chepchumba', 'Kenya', 'No data', None)
# ('Marathon', '2004', 'Athens', 'Mizuki Noguchi', 'Japan', 'No data', None, 'Catherine Ndereba', 'Kenya', 'No data', None, 'Deena Kastor', 'United States', '14-02-1973', 31.0)
# ('Marathon', '2008', 'Beijing', 'Constantina Tomescu', 'Romania', '23-01-1970', 38.0, 'Catherine Ndereba', 'Kenya', 'No data', None, 'Zhou Chunxiu', 'China', 'No data', None)
# ('Marathon', '2012', 'London', 'Tiki Gelana', 'Ethiopia', '22-10-1987', 25.0, 'Priscah Jeptoo', 'Kenya', '26-06-1984', 28.0, 'Tatyana Petrova Arkhipova', 'Russia', '08-04-1983', 29.0)
# ('Marathon', '2016', 'Rio de Janeiro', 'Jemima Sumgong', 'Kenya', '21-12-1984', 32.0, 'Eunice Kirwa', 'Bahrain', '20-05-1984', 32.0, 'Mare Dibaba', 'Ethiopia', '20-10-1989', 27.0)
# ('Marathon', '2020', 'Tokyo', 'Peres Jepchirchir', 'Kenya', 'No data', None, 'Brigid Kosgei', 'Kenya', '20-02-1994', 26.0, 'Molly Seidel', 'United States', '12-07-1994', 26.0)
# ('100 metres hurdles', '1972', 'Munich', 'Annelie Ehrhardt', 'East Germany', '18-06-1950', 22.0, 'Valeria Bufanu', 'Romania', '07-10-1946', 26.0, 'Karin Balzer', 'East Germany', '05-06-1938', 34.0)
# ('100 metres hurdles', '1976', 'Montreal', 'Johanna Schaller-Klier', 'East Germany', 'No data', None, 'Tatyana Anisimova', 'Soviet Union', 'No data', None, 'Natalya Lebedeva', 'Soviet Union', 'No data', None)
# ('100 metres hurdles', '1980', 'Moscow', 'Vera Komisova', 'Soviet Union', '11-06-1953', 27.0, 'Johanna Schaller-Klier', 'East Germany', 'No data', None, 'Lucyna Langer', 'Poland', '09-01-1956', 24.0)
# ('100 metres hurdles', '1984', 'Los Angeles', 'Benita Fitzgerald', 'United States', '06-07-1961', 23.0, 'Shirley Strong', 'Great Britain', '18-11-1958', 26.0, 'Michèle Chardonnet', 'France', '27-10-1956', 28.0)
# ('100 metres hurdles', '1988', 'Seoul', 'Yordanka Donkova', 'Bulgaria', 'No data', None, 'Gloria Siebert', 'East Germany', 'No data', None, 'Claudia Zackiewicz', 'West Germany', 'No data', None)
# ('100 metres hurdles', '1992', 'Barcelona', 'Voula Patoulidou', 'Greece', 'No data', None, 'LaVonna Martin', 'United States', '18-11-1966', 26.0, 'Yordanka Donkova', 'Bulgaria', 'No data', None)
# ('100 metres hurdles', '1996', 'Atlanta', 'Ludmila Engquist', 'Sweden', '21-04-1964', 32.0, 'Brigita Bukovec', 'Slovenia', 'No data', None, 'Patricia Girard', 'France', '08-04-1968', 28.0)
# ('100 metres hurdles', '2000', 'Sydney', 'Olga Shishigina', 'Kazakhstan', '23-12-1968', 32.0, 'Glory Alozie', 'Nigeria', 'No data', None, 'Melissa Morrison', 'United States', '09-07-1971', 29.0)
# ('100 metres hurdles', '2004', 'Athens', 'Joanna Hayes', 'United States', '23-12-1976', 28.0, 'Olena Krasovska', 'Ukraine', 'No data', None, 'Melissa Morrison', 'United States', '09-07-1971', 33.0)
# ('100 metres hurdles', '2008', 'Beijing', 'Dawn Harper', 'United States', '13-05-1984', 24.0, 'Sally Pearson', 'Australia', '19-09-1986', 22.0, 'Priscilla Lopes-Schliep', 'Canada', '26-08-1982', 26.0)
# ('100 metres hurdles', '2012', 'London', 'Sally Pearson', 'Australia', '19-09-1986', 26.0, 'Dawn Harper', 'United States', '13-05-1984', 28.0, 'Kellie Wells', 'United States', '16-07-1982', 30.0)
# ('100 metres hurdles', '2016', 'Rio de Janeiro', 'Brianna Rollins', 'United States', '18-08-1991', 25.0, 'Nia Ali', 'United States', '23-10-1988', 28.0, 'Kristi Castlin', 'United States', '07-07-1988', 28.0)
# ('100 metres hurdles', '2020', 'Tokyo', 'Jasmine Camacho-Quinn', 'Puerto Rico', '21-08-1996', 24.0, 'Kendra Harrison', 'United States', '18-09-1992', 28.0, 'Megan Tapper', 'Jamaica', '18-03-1994', 26.0)
# ('400 metres hurdles', '1984', 'Los Angeles', 'Nawal El Moutawakel', 'Morocco', 'No data', None, 'Judi Brown', 'United States', '14-07-1961', 23.0, 'Cristieana Cojocaru', 'Romania', '02-01-1962', 22.0)
# ('400 metres hurdles', '1988', 'Seoul', 'Debbie Flintoff-King', 'Australia', '20-04-1960', 28.0, 'Tatyana Ledovskaya', 'Soviet Union', 'No data', None, 'Ellen Fiedler', 'East Germany', 'No data', None)
# ('400 metres hurdles', '1992', 'Barcelona', 'Sally Gunnell', 'Great Britain', '29-07-1966', 26.0, 'Sandra Farmer-Patrick', 'United States', '08-08-1962', 30.0, 'Janeene Vickers', 'United States', '03-10-1968', 24.0)
# ('400 metres hurdles', '1996', 'Atlanta', 'Deon Hemmings', 'Jamaica', '09-10-1968', 28.0, 'Kim Batten', 'United States', '29-03-1969', 27.0, 'Tonja Buford-Bailey', 'United States', '13-12-1970', 26.0)
# ('400 metres hurdles', '2000', 'Sydney', 'Irina Privalova', 'Russia', '22-11-1968', 32.0, 'Deon Hemmings', 'Jamaica', '09-10-1968', 32.0, 'Nezha Bidouane', 'Morocco', 'No data', None)
# ('400 metres hurdles', '2004', 'Athens', 'Fani Halkia', 'Greece', 'No data', None, 'Ionela Târlea-Manolache', 'Romania', '09-02-1976', 28.0, 'Tetyana Tereshchuk-Antipova', 'Ukraine', '11-10-1969', 35.0)
# ('400 metres hurdles', '2008', 'Beijing', 'Melaine Walker', 'Jamaica', '01-01-1983', 25.0, 'Sheena Tosta', 'United States', '01-10-1982', 26.0, 'Tasha Danvers', 'Great Britain', '19-09-1977', 31.0)
# ('400 metres hurdles', '2012', 'London', 'Natalya Antyukh', 'Russia', '26-06-1981', 31.0, 'Lashinda Demus', 'United States', '10-03-1983', 29.0, 'Zuzana Hejnová', 'Czech Republic', '19-12-1986', 26.0)
# ('400 metres hurdles', '2016', 'Rio de Janeiro', 'Dalilah Muhammad', 'United States', '07-02-1990', 26.0, 'Sara Petersen', 'Denmark', '09-04-1987', 29.0, 'Ashley Spencer', 'United States', '08-06-1993', 23.0)
# ('400 metres hurdles', '2020', 'Tokyo', 'Sydney McLaughlin', 'United States', '07-08-1999', 21.0, 'Dalilah Muhammad', 'United States', '07-02-1990', 30.0, 'Femke Bol', 'Netherlands', '23-02-2000', 20.0)
# ('3000 metres steeplechase', '2008', 'Beijing[nb]', 'Gulnara Samitova-Galkina', 'Russia', '09-07-1978', 30.0, 'Eunice Jepkorir', 'Kenya', 'No data', None, 'Tatyana Petrova Arkhipova', 'Russia', '08-04-1983', 25.0)
# ('3000 metres steeplechase', '2012', 'London[nb2]', 'Habiba Ghribi', 'Tunisia', '09-04-1984', 28.0, 'Sofia Assefa', 'Ethiopia', '14-11-1987', 25.0, 'Milcah Chemos Cheywa', 'Kenya', 'No data', None)
# ('3000 metres steeplechase', '2016', 'Rio de Janeiro', 'Ruth Jebet', 'Bahrain', '17-11-1996', 20.0, 'Hyvin Kiyeng Jepkemoi', 'Kenya', '13-01-1992', 24.0, 'Emma Coburn', 'United States', '19-10-1990', 26.0)
# ('3000 metres steeplechase', '2020', 'Tokyo', 'Peruth Chemutai', 'Uganda', '10-07-1999', 21.0, 'Courtney Frerichs', 'United States', '18-01-1993', 27.0, 'Hyvin Kiyeng', 'Kenya', '13-01-1992', 28.0)
# ('20 kilometres race walk', '2000', 'Sydney', 'Wang Liping', 'China', 'No data', None, 'Kjersti Plätzer', 'Norway', 'No data', None, 'María Vasco', 'Spain', '26-12-1975', 25.0)
# ('20 kilometres race walk', '2004', 'Athens', 'Athanasia Tsoumeleka', 'Greece', '02-01-1982', 22.0, 'Olimpiada Ivanova', 'Russia', '26-08-1970', 34.0, 'Jane Saville', 'Australia', '05-11-1974', 30.0)
# ('20 kilometres race walk', '2008', 'Beijing', 'Olga Kaniskina', 'Russia', '19-01-1985', 23.0, 'Kjersti Plätzer', 'Norway', 'No data', None, 'Elisa Rigaudo', 'Italy', '17-06-1980', 28.0)
# ('20 kilometres race walk', '2012', 'London', 'Qieyang Shenjie', 'China[10]', '11-11-1990', 22.0, 'Liu Hong', 'China', '12-05-1987', 25.0, 'Lü Xiuzhi', 'China', '26-10-1993', 19.0)
# ('20 kilometres race walk', '2016', 'Rio de Janeiro', 'Liu Hong', 'China', '12-05-1987', 29.0, 'María Guadalupe González', 'Mexico', '09-01-1989', 27.0, 'Lü Xiuzhi', 'China', '26-10-1993', 23.0)
# ('20 kilometres race walk', '2020', 'Tokyo', 'Antonella Palmisano', 'Italy', '06-08-1991', 29.0, 'Sandra Arenas', 'Colombia', '17-09-1993', 27.0, 'Liu Hong', 'China', '12-05-1987', 33.0)
# ('High jump', '1928', 'Amsterdam', 'Ethel Catherwood', 'Canada', '28-04-1908', 20.0, 'Lien Gisolf', 'Netherlands', '13-07-1910', 18.0, 'Mildred Wiley', 'United States', '03-12-1901', 27.0)
# ('High jump', '1932', 'Los Angeles', 'Jean Shiley', 'United States', 'No data', None, 'Babe Didrikson', 'United States', '26-06-1911', 21.0, 'Eva Dawes', 'Canada', '17-09-1912', 20.0)
# ('High jump', '1936', 'Berlin', 'Ibolya Csák', 'Hungary', '06-01-1915', 21.0, 'Dorothy Odam', 'Great Britain', 'No data', None, 'Elfriede Kaun', 'Germany', 'No data', None)
# ('High jump', '1948', 'London', 'Alice Coachman', 'United States', '09-11-1923', 25.0, 'Dorothy Tyler', 'Great Britain', 'No data', None, 'Micheline Ostermeyer', 'France', '23-12-1922', 26.0)
# ('High jump', '1952', 'Helsinki', 'Esther Brand', 'South Africa', '29-09-1922', 30.0, 'Sheile Lerwill', 'Great Britain', 'No data', None, 'Aleksandra Chudina', 'Soviet Union', '06-11-1923', 29.0)
# ('High jump', '1956', 'Melbourne', 'Mildred McDaniel', 'United States', '04-11-1933', 23.0, 'Thelma Hopkins', 'Great Britain', '16-03-1936', 20.0, 'none awarded', 'n/a', 'n/a', None)
# ('High jump', '1960', 'Rome', 'Iolanda Balaș', 'Romania', '12-12-1936', 24.0, 'Jarosława Jóźwiakowska', 'Poland', 'No data', None, 'none awarded', 'n/a', 'n/a', None)
# ('High jump', '1964', 'Tokyo', 'Iolanda Balaș', 'Romania', '12-12-1936', 28.0, 'Michele Brown', 'Australia', '03-07-1939', 25.0, 'Taisia Chenchik', 'Soviet Union', '30-01-1936', 28.0)
# ('High jump', '1968', 'Mexico City', 'Miloslava Rezková', 'Czechoslovakia', '22-07-1950', 18.0, 'Antonina Okorokova', 'Soviet Union', 'No data', None, 'Valentina Kozyr', 'Soviet Union', 'No data', None)
# ('High jump', '1972', 'Munich', 'Ulrike Meyfarth', 'West Germany', '04-05-1956', 16.0, 'Yordanka Blagoeva', 'Bulgaria', '19-01-1947', 25.0, 'Ilona Gusenbauer', 'Austria', '16-09-1947', 25.0)
# ('High jump', '1976', 'Montreal', 'Rosemarie Ackermann', 'East Germany', 'No data', None, 'Sara Simeoni', 'Italy', '19-04-1953', 23.0, 'Yordanka Blagoeva', 'Bulgaria', '19-01-1947', 29.0)
# ('High jump', '1980', 'Moscow', 'Sara Simeoni', 'Italy', '19-04-1953', 27.0, 'Urszula Kielan', 'Poland', '10-10-1960', 20.0, 'Jutta Kirst', 'East Germany', 'No data', None)
# ('High jump', '1984', 'Los Angeles', 'Ulrike Meyfarth', 'West Germany', '04-05-1956', 28.0, 'Sara Simeoni', 'Italy', '19-04-1953', 31.0, 'Joni Huntley', 'United States', '04-08-1956', 28.0)
# ('High jump', '1988', 'Seoul', 'Louise Ritter', 'United States', '18-02-1958', 30.0, 'Stefka Kostadinova', 'Bulgaria', '25-03-1965', 23.0, 'Tamara Bykova', 'Soviet Union', '21-12-1958', 30.0)
# ('High jump', '1992', 'Barcelona', 'Heike Henkel', 'Germany', 'No data', None, 'Alina Astafei', 'Romania', '07-06-1969', 23.0, 'Ioamnet Quintero', 'Cuba', '08-09-1972', 20.0)
# ('High jump', '1996', 'Atlanta', 'Stefka Kostadinova', 'Bulgaria', '25-03-1965', 31.0, 'Niki Bakoyianni', 'Greece', 'No data', None, 'Inha Babakova', 'Ukraine', '26-06-1967', 29.0)
# ('High jump', '2000', 'Sydney', 'Yelena Yelesina', 'Russia', 'No data', None, 'Hestrie Cloete', 'South Africa', '26-08-1978', 22.0, 'Kajsa Bergqvist', 'Sweden', '12-10-1976', 24.0)
# ('High jump', '2004', 'Athens', 'Yelena Slesarenko', 'Russia', '28-02-1982', 22.0, 'Hestrie Cloete', 'South Africa', '26-08-1978', 26.0, 'Vita Styopina', 'Ukraine', '21-02-1976', 28.0)
# ('High jump', '2008', 'Beijing', 'Tia Hellebaut', 'Belgium', '16-02-1978', 30.0, 'Blanka Vlašić', 'Croatia', '08-11-1983', 25.0, 'Chaunté Howard', 'United States', '12-01-1984', 24.0)
# ('High jump', '2012', 'London', 'Anna Chicherova', 'Russia', '22-07-1982', 30.0, 'Brigetta Barrett', 'United States', '24-12-1990', 22.0, 'Ruth Beitia', 'Spain', '01-04-1979', 33.0)
# ('High jump', '2016', 'Rio de Janeiro', 'Ruth Beitia', 'Spain', '01-04-1979', 37.0, 'Mirela Demireva', 'Bulgaria', '28-09-1989', 27.0, 'Blanka Vlašić', 'Croatia', '08-11-1983', 33.0)
# ('High jump', '2020', 'Tokyo', 'Mariya Lasitskene', 'ROC', '14-01-1993', 27.0, 'Nicola McDermott', 'Australia', '28-12-1996', 24.0, 'Yaroslava Mahuchikh', 'Ukraine', '19-09-2001', 19.0)
# ('Pole vault', '2000', 'Sydney', 'Stacy Dragila', 'United States', '25-03-1971', 29.0, 'Tatiana Grigorieva', 'Australia', 'No data', None, 'Vala Flosadóttir', 'Iceland', 'No data', None)
# ('Pole vault', '2004', 'Athens', 'Yelena Isinbayeva', 'Russia', '03-06-1982', 22.0, 'Svetlana Feofanova', 'Russia', '16-07-1980', 24.0, 'Anna Rogowska', 'Poland', '21-05-1981', 23.0)
# ('Pole vault', '2008', 'Beijing', 'Yelena Isinbayeva', 'Russia', '03-06-1982', 26.0, 'Jennifer Stuczynski', 'United States', 'No data', None, 'Svetlana Feofanova', 'Russia', '16-07-1980', 28.0)
# ('Pole vault', '2012', 'London', 'Jennifer Suhr', 'United States', 'No data', None, 'Yarisley Silva', 'Cuba', '01-06-1987', 25.0, 'Yelena Isinbayeva', 'Russia', '03-06-1982', 30.0)
# ('Pole vault', '2016', 'Rio de Janeiro', 'Katerina Stefanidi', 'Greece', '04-02-1990', 26.0, 'Sandi Morris', 'United States', '08-07-1992', 24.0, 'Eliza McCartney', 'New Zealand', '11-12-1996', 20.0)
# ('Pole vault', '2020', 'Tokyo', 'Katie Nageotte', 'United States', '13-06-1991', 29.0, 'Anzhelika Sidorova', 'ROC', '28-06-1991', 29.0, 'Holly Bradshaw', 'Great Britain', '02-11-1991', 29.0)
# ('Long jump', '1948', 'London', 'Olga Gyarmati', 'Hungary', '05-10-1924', 24.0, 'Noemí Simonetto', 'Argentina', 'No data', None, 'Ann-Britt Leyman', 'Sweden', '10-06-1922', 26.0)
# ('Long jump', '1952', 'Helsinki', 'Yvette Williams', 'New Zealand', '25-04-1929', 23.0, 'Aleksandra Chudina', 'Soviet Union', '06-11-1923', 29.0, 'Shirley Cawley', 'Great Britain', 'No data', None)
# ('Long jump', '1956', 'Melbourne', 'Elżbieta Krzesińska', 'Poland', 'No data', None, 'Willye White', 'United States', '31-12-1939', 17.0, 'Nadezhda Khnykina-Dvalishvili', 'Soviet Union', 'No data', None)
# ('Long jump', '1960', 'Rome', 'Vera Krepkina', 'Soviet Union', '15-04-1933', 27.0, 'Elżbieta Krzesińska', 'Poland', 'No data', None, 'Hildrun Claus', 'United Team of Germany', '13-05-1939', 21.0)
# ('Long jump', '1964', 'Tokyo', 'Mary Rand', 'Great Britain', '10-02-1940', 24.0, 'Irena Kirszenstein', 'Poland', '24-05-1946', 18.0, 'Tatyana Shchelkanova', 'Soviet Union', '18-04-1937', 27.0)
# ('Long jump', '1968', 'Mexico City', 'Viorica Viscopoleanu', 'Romania', '08-08-1939', 29.0, 'Sheila Sherwood', 'Great Britain', 'No data', None, 'Tatyana Talysheva', 'Soviet Union', 'No data', None)
# ('Long jump', '1972', 'Munich', 'Heide Rosendahl', 'West Germany', '14-02-1947', 25.0, 'Diana Yorgova', 'Bulgaria', 'No data', None, 'Eva Šuranová', 'Czechoslovakia', 'No data', None)
# ('Long jump', '1976', 'Montreal', 'Angela Voigt', 'East Germany', '18-05-1951', 25.0, 'Kathy McMillan', 'United States', '07-11-1957', 19.0, 'Lidiya Alfeyeva', 'Soviet Union', '17-01-1946', 30.0)
# ('Long jump', '1980', 'Moscow', 'Tatyana Kolpakova', 'Soviet Union', 'No data', None, 'Brigitte Wujak', 'East Germany', 'No data', None, 'Tatyana Skachko', 'Soviet Union', 'No data', None)
# ('Long jump', '1984', 'Los Angeles', 'Anișoara Cușmir-Stanciu', 'Romania', '29-06-1962', 22.0, 'Valy Ionescu', 'Romania', '31-08-1960', 24.0, 'Sue Hearnshaw', 'Great Britain', 'No data', None)
# ('Long jump', '1988', 'Seoul', 'Jackie Joyner-Kersee', 'United States', '03-03-1962', 26.0, 'Heike Drechsler', 'East Germany', '16-12-1964', 24.0, 'Galina Chistyakova', 'Soviet Union', '26-07-1962', 26.0)
# ('Long jump', '1992', 'Barcelona', 'Heike Drechsler', 'Germany', '16-12-1964', 28.0, 'Inessa Kravets', 'Unified Team', '05-10-1966', 26.0, 'Jackie Joyner-Kersee', 'United States', '03-03-1962', 30.0)
# ('Long jump', '1996', 'Atlanta', 'Chioma Ajunwa', 'Nigeria', '25-12-1970', 26.0, 'Fiona May', 'Italy', '12-12-1969', 27.0, 'Jackie Joyner-Kersee', 'United States', '03-03-1962', 34.0)
# ('Long jump', '2000', 'Sydney', 'Heike Drechsler', 'Germany', '16-12-1964', 36.0, 'Fiona May', 'Italy', '12-12-1969', 31.0, 'Tatyana Kotova', 'Russia', '11-12-1976', 24.0)
# ('Long jump', '2004', 'Athens', 'Tatyana Lebedeva', 'Russia', '21-07-1976', 28.0, 'Irina Simagina', 'Russia', '25-05-1982', 22.0, 'Tatyana Kotova', 'Russia', '11-12-1976', 28.0)
# ('Long jump', '2008', 'Beijing', 'Maurren Maggi', 'Brazil', '25-06-1976', 32.0, 'Blessing Okagbare', 'Nigeria', '09-10-1988', 20.0, 'Chelsea Hammond', 'Jamaica', '02-08-1982', 26.0)
# ('Long jump', '2012', 'London', 'Brittney Reese', 'United States', '09-09-1986', 26.0, 'Elena Sokolova', 'Russia', '23-07-1986', 26.0, 'Janay DeLoach', 'United States', '12-10-1985', 27.0)
# ('Long jump', '2016', 'Rio de Janeiro', 'Tianna Bartoletta', 'United States', '30-08-1985', 31.0, 'Britney Reese', 'United States', '09-09-1986', 30.0, 'Ivana Španović', 'Serbia', '10-05-1990', 26.0)
# ('Long jump', '2020', 'Tokyo', 'Malaika Mihambo', 'Germany', '03-02-1994', 26.0, 'Britney Reese', 'United States', '09-09-1986', 34.0, 'Ese Brume', 'Nigeria', '20-01-1996', 24.0)
# ('Triple jump', '1996', 'Atlanta', 'Inessa Kravets', 'Ukraine', '05-10-1966', 30.0, 'Inna Lasovskaya', 'Russia', 'No data', None, 'Šárka Kašpárková', 'Czech Republic', 'No data', None)
# ('Triple jump', '2000', 'Sydney', 'Tereza Marinova', 'Bulgaria', '05-09-1977', 23.0, 'Tatyana Lebedeva', 'Russia', '21-07-1976', 24.0, 'Olena Hovorova', 'Ukraine', 'No data', None)
# ('Triple jump', '2004', 'Athens', 'Françoise Mbango Etone', 'Cameroon', 'No data', None, 'Hrysopiyí Devetzí', 'Greece', '02-01-1976', 28.0, 'Tatyana Lebedeva', 'Russia', '21-07-1976', 28.0)
# ('Triple jump', '2008', 'Beijing', 'Françoise Mbango Etone', 'Cameroon', 'No data', None, 'Olga Rypakova', 'Kazakhstan', '30-11-1984', 24.0, 'Yargelis Savigne', 'Cuba', '13-11-1984', 24.0)
# ('Triple jump', '2012', 'London', 'Olga Rypakova', 'Kazakhstan', '30-11-1984', 28.0, 'Caterine Ibargüen', 'Colombia', '12-02-1984', 28.0, 'Olha Saladukha', 'Ukraine', '04-06-1983', 29.0)
# ('Triple jump', '2016', 'Rio de Janeiro', 'Caterine Ibargüen', 'Colombia', '12-02-1984', 32.0, 'Yulimar Rojas', 'Venezuela', '21-10-1995', 21.0, 'Olga Rypakova', 'Kazakhstan', '30-11-1984', 32.0)
# ('Triple jump', '2020', 'Tokyo', 'Yulimar Rojas', 'Venezuela', '21-10-1995', 25.0, 'Patrícia Mamona', 'Portugal', '21-11-1988', 32.0, 'Ana Peleteiro', 'Spain', 'No data', None)
# ('Shot put', '1948', 'London', 'Micheline Ostermeyer', 'France', '23-12-1922', 26.0, 'Amelia Piccinini', 'Italy', '20-01-1917', 31.0, 'Ina Schäffer', 'Austria', 'No data', None)
# ('Shot put', '1952', 'Helsinki', 'Galina Zybina', 'Soviet Union', '22-01-1931', 21.0, 'Marianne Werner', 'Germany', '04-01-1924', 28.0, 'Klavdiya Tochenova', 'Soviet Union', '16-11-1921', 31.0)
# ('Shot put', '1956', 'Melbourne', 'Tamara Tyshkevich', 'Soviet Union', '31-03-1931', 25.0, 'Galina Zybina', 'Soviet Union', '22-01-1931', 25.0, 'Marianne Werner', 'United Team of Germany', '04-01-1924', 32.0)
# ('Shot put', '1960', 'Rome', 'Tamara Press', 'Soviet Union', '10-05-1937', 23.0, 'Johanna Lüttge', 'United Team of Germany', '10-03-1936', 24.0, 'Earlene Brown', 'United States', '11-07-1935', 25.0)
# ('Shot put', '1964', 'Tokyo', 'Tamara Press', 'Soviet Union', '10-05-1937', 27.0, 'Renate Culmberger', 'United Team of Germany', '24-01-1939', 25.0, 'Galina Zybina', 'Soviet Union', '22-01-1931', 33.0)
# ('Shot put', '1968', 'Mexico City', 'Margitta Gummel', 'East Germany', '29-06-1941', 27.0, 'Marita Lange', 'East Germany', '22-06-1943', 25.0, 'Nadezhda Chizhova', 'Soviet Union', '29-09-1945', 23.0)
# ('Shot put', '1972', 'Munich', 'Nadezhda Chizhova', 'Soviet Union', '29-09-1945', 27.0, 'Margitta Gummel', 'East Germany', '29-06-1941', 31.0, 'Ivanka Khristova', 'Bulgaria', '19-11-1941', 31.0)
# ('Shot put', '1976', 'Montreal', 'Ivanka Khristova', 'Bulgaria', '19-11-1941', 35.0, 'Nadezhda Chizhova', 'Soviet Union', '29-09-1945', 31.0, 'Helena Fibingerová', 'Czechoslovakia', '13-07-1949', 27.0)
# ('Shot put', '1980', 'Moscow', 'Ilona Slupianek', 'East Germany', '24-09-1956', 24.0, 'Svetlana Krachevskaya', 'Soviet Union', 'No data', None, 'Margitta Pufe', 'East Germany', '10-09-1952', 28.0)
# ('Shot put', '1984', 'Los Angeles', 'Claudia Losch', 'West Germany', '10-01-1960', 24.0, 'Mihaela Loghin', 'Romania', '01-06-1952', 32.0, 'Gael Martin', 'Australia', '27-08-1956', 28.0)
# ('Shot put', '1988', 'Seoul', 'Natalya Lisovskaya', 'Soviet Union', '16-07-1962', 26.0, 'Kathrin Neimke', 'East Germany', '18-07-1966', 22.0, 'Li Meisu', 'China', '17-04-1959', 29.0)
# ('Shot put', '1992', 'Barcelona', 'Svetlana Krivelyova', 'Unified Team', 'No data', None, 'Huang Zhihong', 'China', 'No data', None, 'Kathrin Neimke', 'Germany', '18-07-1966', 26.0)
# ('Shot put', '1996', 'Atlanta', 'Astrid Kumbernuss', 'Germany', '05-02-1970', 26.0, 'Sui Xinmei', 'China', 'No data', None, 'Irina Khudoroshkina', 'Russia', 'No data', None)
# ('Shot put', '2000', 'Sydney', 'Yanina Karolchik', 'Belarus', '26-12-1976', 24.0, 'Larisa Peleshenko', 'Russia', '29-02-1964', 36.0, 'Astrid Kumbernuss', 'Germany', '05-02-1970', 30.0)
# ('Shot put', '2004', 'Athens', 'Yumileidi Cumbá', 'Cuba', '11-02-1975', 29.0, 'Nadine Kleinert', 'Germany', '20-10-1975', 29.0, 'Not awarded[11]\n', 'n/a', 'n/a', None)
# ('Shot put', '2008', 'Beijing', 'Valerie Vili', 'New Zealand', '06-10-1984', 24.0, 'Misleydis González', 'Cuba', '19-06-1978', 30.0, 'Gong Lijiao', 'China', '24-01-1989', 19.0)
# ('Shot put', '2012', 'London', 'Valerie Adams', 'New Zealand', '06-10-1984', 28.0, 'Gong Lijiao', 'China', '24-01-1989', 23.0, 'Li Ling', 'China', '07-02-1985', 27.0)
# ('Shot put', '2016', 'Rio de Janeiro', 'Michelle Carter', 'United States', '12-10-1985', 31.0, 'Valerie Adams', 'New Zealand', '06-10-1984', 32.0, 'Anita Márton', 'Hungary', '15-01-1989', 27.0)
# ('Shot put', '2020', 'Tokyo', 'Gong Lijiao', 'China', '24-01-1989', 31.0, 'Raven Saunders', 'United States', '15-05-1996', 24.0, 'Valerie Adams', 'New Zealand', '06-10-1984', 36.0)
# ('Discus throw', '1928', 'Amsterdam', 'Halina Konopacka', 'Poland', '26-02-1900', 28.0, 'Lillian Copeland', 'United States', '24-11-1904', 24.0, 'Ruth Svedberg', 'Sweden', '14-04-1903', 25.0)
# ('Discus throw', '1932', 'Los Angeles', 'Lillian Copeland', 'United States', '24-11-1904', 28.0, 'Ruth Osburn', 'United States', 'No data', None, 'Jadwiga Wajs', 'Poland', '30-01-1912', 20.0)
# ('Discus throw', '1936', 'Berlin', 'Gisela Mauermayer', 'Germany', 'No data', None, 'Jadwiga Wajs', 'Poland', '30-01-1912', 24.0, 'Paula Mollenhauer', 'Germany', 'No data', None)
# ('Discus throw', '1948', 'London', 'Micheline Ostermeyer', 'France', '23-12-1922', 26.0, 'Edera Gentile', 'Italy', '30-01-1920', 28.0, 'Jacqueline Mazéas', 'France', 'No data', None)
# ('Discus throw', '1952', 'Helsinki', 'Nina Romashkova', 'Soviet Union', '27-04-1929', 23.0, 'Yelisaveta Bagriantseva', 'Soviet Union', '27-08-1929', 23.0, 'Nina Dumbadze', 'Soviet Union', '23-05-1919', 33.0)
# ('Discus throw', '1956', 'Melbourne', 'Olga Fikotová', 'Czechoslovakia', '13-11-1932', 24.0, 'Irina Beglyakova', 'Soviet Union', 'No data', None, 'Nina Romashkova', 'Soviet Union', '27-04-1929', 27.0)
# ('Discus throw', '1960', 'Rome', 'Nina Romashkova', 'Soviet Union', '27-04-1929', 31.0, 'Tamara Press', 'Soviet Union', '10-05-1937', 23.0, 'Lia Manoliu', 'Romania', '25-04-1932', 28.0)
# ('Discus throw', '1964', 'Tokyo', 'Tamara Press', 'Soviet Union', '10-05-1937', 27.0, 'Ingrid Lotz', 'United Team of Germany', '11-03-1934', 30.0, 'Lia Manoliu', 'Romania', '25-04-1932', 32.0)
# ('Discus throw', '1968', 'Mexico City', 'Lia Manoliu', 'Romania', '25-04-1932', 36.0, 'Liesel Westermann', 'West Germany', '02-11-1944', 24.0, 'Jolán Kleiber-Kontsek', 'Hungary', '29-08-1939', 29.0)
# ('Discus throw', '1972', 'Munich', 'Faina Melnik', 'Soviet Union', '09-06-1945', 27.0, 'Argentina Menis', 'Romania', '19-07-1948', 24.0, 'Vasilka Stoeva', 'Bulgaria', 'No data', None)
# ('Discus throw', '1976', 'Montreal', 'Evelin Schlaak', 'East Germany', '28-03-1956', 20.0, 'Mariya Vergova', 'Bulgaria', '03-11-1950', 26.0, 'Gabriele Hinzmann', 'East Germany', '31-05-1947', 29.0)
# ('Discus throw', '1980', 'Moscow', 'Evelin Jahl', 'East Germany', '28-03-1956', 24.0, 'Mariya Petkova', 'Bulgaria', '03-11-1950', 30.0, 'Tatyana Lesovaya', 'Soviet Union', 'No data', None)
# ('Discus throw', '1984', 'Los Angeles', 'Ria Stalman', 'Netherlands', '11-12-1951', 33.0, 'Leslie Deniz', 'United States', '25-05-1962', 22.0, 'Florența Crăciunescu', 'Romania', '07-05-1955', 29.0)
# ('Discus throw', '1988', 'Seoul', 'Martina Hellmann', 'East Germany', '12-12-1960', 28.0, 'Diana Gansky', 'East Germany', '14-12-1963', 25.0, 'Tsvetanka Khristova', 'Bulgaria', '14-03-1962', 26.0)
# ('Discus throw', '1992', 'Barcelona', 'Maritza Martén', 'Cuba', '17-08-1963', 29.0, 'Tsvetanka Khristova', 'Bulgaria', '14-03-1962', 30.0, 'Daniela Costian', 'Australia', '30-04-1965', 27.0)
# ('Discus throw', '1996', 'Atlanta', 'Ilke Wyludda', 'Germany', '28-03-1969', 27.0, 'Natalya Sadova', 'Russia', '15-07-1972', 24.0, 'Ellina Zvereva', 'Belarus', '16-11-1960', 36.0)
# ('Discus throw', '2000', 'Sydney', 'Ellina Zvereva', 'Belarus', '16-11-1960', 40.0, 'Anastasia Kelesidou', 'Greece', 'No data', None, 'Iryna Yatchenko', 'Belarus', '31-10-1965', 35.0)
# ('Discus throw', '2004', 'Athens', 'Natalya Sadova', 'Russia', '15-07-1972', 32.0, 'Anastasia Kelesidou', 'Greece', 'No data', None, 'Věra Pospíšilová-Cechlová', 'Czech Republic[12]', '19-11-1978', 26.0)
# ('Discus throw', '2008', 'Beijing', 'Stephanie Brown Trafton', 'United States', '01-12-1979', 29.0, 'Olena Antonova', 'Ukraine', '16-06-1972', 36.0, 'Song Aimin', 'China', 'No data', None)
# ('Discus throw', '2012', 'London', 'Sandra Perković', 'Croatia', '21-06-1990', 22.0, 'Li Yanfeng', 'China', '15-05-1979', 33.0, 'Yarelys Barrios', 'Cuba', '12-07-1983', 29.0)
# ('Discus throw', '2016', 'Rio de Janeiro', 'Sandra Perković', 'Croatia', '21-06-1990', 26.0, 'Mélina Robert-Michon', 'France', '18-07-1979', 37.0, 'Denia Caballero', 'Cuba', '13-01-1990', 26.0)
# ('Discus throw', '2020', 'Tokyo', 'Valarie Allman', 'United States', '23-02-1995', 25.0, 'Kristin Pudenz', 'Germany', '09-02-1993', 27.0, 'Yaime Pérez', 'Cuba', '29-05-1991', 29.0)
# ('Hammer throw', '2000', 'Sydney', 'Kamila Skolimowska', 'Poland', '04-11-1982', 18.0, 'Olga Kuzenkova', 'Russia', '04-10-1970', 30.0, 'Kirsten Münchow', 'Germany', '21-01-1977', 23.0)
# ('Hammer throw', '2004', 'Athens', 'Olga Kuzenkova', 'Russia', '04-10-1970', 34.0, 'Yipsi Moreno', 'Cuba', '19-11-1980', 24.0, 'Yunaika Crawford', 'Cuba', '02-11-1982', 22.0)
# ('Hammer throw', '2008', 'Beijing', 'Yipsi Moreno', 'Cuba', '19-11-1980', 28.0, 'Zhang Wenxiu', 'China', '22-03-1986', 22.0, 'Manuela Montebrun', 'France', '13-11-1979', 29.0)
# ('Hammer throw', '2012', 'London', 'Anita Włodarczyk', 'Poland', '08-08-1985', 27.0, 'Betty Heidler', 'Germany', '14-10-1983', 29.0, 'Zhang Wenxiu', 'China', '22-03-1986', 26.0)
# ('Hammer throw', '2016', 'Rio de Janeiro', 'Anita Włodarczyk', 'Poland', '08-08-1985', 31.0, 'Zhang Wenxiu', 'China', '22-03-1986', 30.0, 'Sophie Hitchon', 'Great Britain', '11-07-1991', 25.0)
# ('Hammer throw', '2020', 'Tokyo', 'Anita Włodarczyk', 'Poland', '08-08-1985', 35.0, 'Wang Zheng', 'China', '14-12-1987', 33.0, 'Malwina Kopron', 'Poland', '16-11-1994', 26.0)
# ('Javelin throw', '1932', 'Los Angeles', 'Babe Didrikson', 'United States', '26-06-1911', 21.0, 'Ellen Braumüller', 'Germany', 'No data', None, 'Tilly Fleischer', 'Germany', '02-10-1911', 21.0)
# ('Javelin throw', '1936', 'Berlin', 'Tilly Fleischer', 'Germany', '02-10-1911', 25.0, 'Luise Krüger', 'Germany', 'No data', None, 'Maria Kwaśniewska', 'Poland', '15-08-1913', 23.0)
# ('Javelin throw', '1948', 'London', 'Herma Bauma', 'Austria', 'No data', None, 'Kaisa Parviainen', 'Finland', '03-12-1914', 34.0, 'Lily Carlstedt', 'Denmark', 'No data', None)
# ('Javelin throw', '1952', 'Helsinki', 'Dana Zátopková', 'Czechoslovakia', '19-09-1922', 30.0, 'Aleksandra Chudina', 'Soviet Union', '06-11-1923', 29.0, 'Yelena Gorchakova', 'Soviet Union', '17-05-1933', 19.0)
# ('Javelin throw', '1956', 'Melbourne', 'Inese Jaunzeme', 'Soviet Union', '21-05-1932', 24.0, 'Marlene Ahrens', 'Chile', 'No data', None, 'Nadezhda Konyayeva', 'Soviet Union', 'No data', None)
# ('Javelin throw', '1960', 'Rome', 'Elvīra Ozoliņa', 'Soviet Union', '08-10-1939', 21.0, 'Dana Zátopková', 'Czechoslovakia', '19-09-1922', 38.0, 'Birutė Kalėdienė', 'Soviet Union', '02-11-1934', 26.0)
# ('Javelin throw', '1964', 'Tokyo', 'Mihaela Peneș', 'Romania', '22-07-1947', 17.0, 'Márta Rudas', 'Hungary', '14-02-1937', 27.0, 'Yelena Gorchakova', 'Soviet Union', '17-05-1933', 31.0)
# ('Javelin throw', '1968', 'Mexico City', 'Angéla Németh', 'Hungary', '18-02-1946', 22.0, 'Mihaela Peneș', 'Romania', '22-07-1947', 21.0, 'Eva Janko', 'Austria', '24-01-1945', 23.0)
# ('Javelin throw', '1972', 'Munich', 'Ruth Fuchs', 'East Germany', '14-12-1946', 26.0, 'Jacqueline Todten', 'East Germany', '29-05-1954', 18.0, 'Kate Schmidt', 'United States', '29-12-1953', 19.0)
# ('Javelin throw', '1976', 'Montreal', 'Ruth Fuchs', 'East Germany', '14-12-1946', 30.0, 'Marion Becker', 'West Germany', '21-01-1950', 26.0, 'Kate Schmidt', 'United States', '29-12-1953', 23.0)
# ('Javelin throw', '1980', 'Moscow', 'María Caridad Colón', 'Cuba', '25-03-1958', 22.0, 'Saida Gunba', 'Soviet Union', 'No data', None, 'Ute Hommola', 'East Germany', '20-01-1952', 28.0)
# ('Javelin throw', '1984', 'Los Angeles', 'Tessa Sanderson', 'Great Britain', '14-03-1956', 28.0, 'Tiina Lillak', 'Finland', '15-04-1961', 23.0, 'Fatima Whitbread', 'Great Britain', '03-03-1961', 23.0)
# ('Javelin throw', '1988', 'Seoul', 'Petra Felke', 'East Germany', '30-07-1959', 29.0, 'Fatima Whitbread', 'Great Britain', '03-03-1961', 27.0, 'Beate Koch', 'East Germany', '18-08-1967', 21.0)
# ('Javelin throw', '1992', 'Barcelona', 'Silke Renk', 'Germany', '30-06-1967', 25.0, 'Natalya Shikolenko', 'Unified Team', '01-08-1964', 28.0, 'Karen Forkel', 'Germany', '24-09-1970', 22.0)
# ('Javelin throw', '1996', 'Atlanta', 'Heli Rantanen', 'Finland', 'No data', None, 'Louise McPaul', 'Australia', 'No data', None, 'Trine Hattestad', 'Norway', '18-04-1966', 30.0)
# ('Javelin throw', '2000', 'Sydney', 'Trine Hattestad', 'Norway', '18-04-1966', 34.0, 'Mirela Maniani-Tzelili', 'Greece', '21-12-1976', 24.0, 'Osleidys Menéndez', 'Cuba', '14-11-1979', 21.0)
# ('Javelin throw', '2004', 'Athens', 'Osleidys Menéndez', 'Cuba', '14-11-1979', 25.0, 'Steffi Nerius', 'Germany', '01-07-1972', 32.0, 'Mirela Maniani', 'Greece', '21-12-1976', 28.0)
# ('Javelin throw', '2008', 'Beijing', 'Barbora Špotáková', 'Czech Republic', '30-06-1981', 27.0, 'Christina Obergföll', 'Germany[13]', '22-08-1981', 27.0, 'Goldie Sayers', 'Great Britain', '16-07-1982', 26.0)
# ('Javelin throw', '2012', 'London', 'Barbora Špotáková', 'Czech Republic', '30-06-1981', 31.0, 'Christina Obergföll', 'Germany', '22-08-1981', 31.0, 'Linda Stahl', 'Germany', '02-10-1985', 27.0)
# ('Javelin throw', '2016', 'Rio de Janeiro', 'Sara Kolak', 'Croatia', '22-06-1995', 21.0, 'Sunette Viljoen', 'South Africa', '06-10-1983', 33.0, 'Barbora Špotáková', 'Czech Republic', '30-06-1981', 35.0)
# ('Javelin throw', '2020', 'Tokyo', 'Liu Shiying', 'China', '24-09-1993', 27.0, 'Maria Andrejczyk', 'Poland', '09-03-1996', 24.0, 'Kelsey-Lee Barber', 'Australia', '20-09-1991', 29.0)
# ('Heptathlon', '1984', 'Los Angeles', 'Glynis Nunn', 'Australia', 'No data', None, 'Jackie Joyner', 'United States', '03-03-1962', 22.0, 'Sabine Everts', 'West Germany', '04-03-1961', 23.0)
# ('Heptathlon', '1988', 'Seoul', 'Jackie Joyner-Kersee', 'United States', '03-03-1962', 26.0, 'Sabine John', 'East Germany', '16-10-1957', 31.0, 'Anke Behmer', 'East Germany', '05-06-1961', 27.0)
# ('Heptathlon', '1992', 'Barcelona', 'Jackie Joyner-Kersee', 'United States', '03-03-1962', 30.0, 'Irina Belova', 'Unified Team', 'No data', None, 'Sabine Braun', 'Germany', 'No data', None)
# ('Heptathlon', '1996', 'Atlanta', 'Ghada Shouaa', 'Syria', '10-09-1972', 24.0, 'Natallia Sazanovich', 'Belarus', 'No data', None, 'Denise Lewis', 'Great Britain', '27-08-1972', 24.0)
# ('Heptathlon', '2000', 'Sydney', 'Denise Lewis', 'Great Britain', '27-08-1972', 28.0, 'Yelena Prokhorova', 'Russia', 'No data', None, 'Natallia Sazanovich', 'Belarus', 'No data', None)
# ('Heptathlon', '2004', 'Athens', 'Carolina Klüft', 'Sweden', '02-02-1983', 21.0, 'Austra Skujytė', 'Lithuania', '12-08-1979', 25.0, 'Kelly Sotherton', 'Great Britain', '13-11-1976', 28.0)
# ('Heptathlon', '2008', 'Beijing', 'Nataliya Dobrynska', 'Ukraine', '29-05-1982', 26.0, 'Hyleas Fountain', 'United States', '14-01-1981', 27.0, 'Kelly Sotherton', 'Great Britain', '13-11-1976', 32.0)
# ('Heptathlon', '2012', 'London', 'Jessica Ennis', 'Great Britain', '28-01-1986', 26.0, 'Lilli Schwarzkopf', 'Germany', '28-08-1983', 29.0, 'Austra Skujytė', 'Lithuania', '12-08-1979', 33.0)
# ('Heptathlon', '2016', 'Rio de Janeiro', 'Nafissatou Thiam', 'Belgium', '19-08-1994', 22.0, 'Jessica Ennis-Hill', 'Great Britain', '28-01-1986', 30.0, 'Brianne Theisen-Eaton', 'Canada', '18-12-1988', 28.0)
# ('Heptathlon', '2020', 'Tokyo', 'Nafissatou Thiam', 'Belgium', '19-08-1994', 26.0, 'Anouk Vetter', 'Netherlands', '04-02-1993', 27.0, 'Emma Oosterwegel', 'Netherlands', '29-06-1998', 22.0)
# ('3000 metres', '1984', 'Los Angeles', 'Maricica Puică', 'Romania', '29-07-1950', 34.0, 'Wendy Smith-Sly', 'Great Britain', '05-11-1959', 25.0, 'Lynn Williams', 'Canada', 'No data', None)
# ('3000 metres', '1988', 'Seoul', 'Tetyana Samolenko', 'Soviet Union', '12-08-1961', 27.0, 'Paula Ivan', 'Romania', '20-07-1963', 25.0, 'Yvonne Murray', 'Great Britain', 'No data', None)
# ('3000 metres', '1992', 'Barcelona', 'Yelena Romanova', 'Unified Team', '20-03-1963', 29.0, 'Tetyana Dorovskikh', 'Unified Team', '12-08-1961', 31.0, 'Angela Chalmers', 'Canada', 'No data', None)
# ('80 metres hurdles', '1932', 'Los Angeles', 'Babe Didrikson', 'United States', '26-06-1911', 21.0, 'Evelyne Hall', 'United States', '10-09-1909', 23.0, 'Marjorie Clark', 'South Africa', '06-11-1909', 23.0)
# ('80 metres hurdles', '1936', 'Berlin', 'Ondina Valla', 'Italy', '20-05-1916', 20.0, 'Anni Steuer', 'Germany', 'No data', None, 'Elizabeth Taylor', 'Canada', 'No data', None)
# ('80 metres hurdles', '1948', 'London', 'Fanny Blankers-Koen', 'Netherlands', '26-04-1918', 30.0, 'Maureen Gardner', 'Great Britain', '12-11-1928', 20.0, 'Shirley Strickland', 'Australia', '18-07-1925', 23.0)
# ('80 metres hurdles', '1952', 'Helsinki', 'Shirley Strickland de la Hunty', 'Australia', '18-07-1925', 27.0, 'Maria Golubnichaya', 'Soviet Union', 'No data', None, 'Maria Sander', 'Germany', 'No data', None)
# ('80 metres hurdles', '1956', 'Melbourne', 'Shirley Strickland de la Hunty', 'Australia', '18-07-1925', 31.0, 'Gisela Köhler', 'United Team of Germany', '22-12-1931', 25.0, 'Norma Thrower', 'Australia', 'No data', None)
# ('80 metres hurdles', '1960', 'Rome', 'Irina Press', 'Soviet Union', '10-03-1939', 21.0, 'Carole Quinton', 'Great Britain', 'No data', None, 'Gisela Birkemeyer', 'United Team of Germany', '22-12-1931', 29.0)
# ('80 metres hurdles', '1964', 'Tokyo', 'Karin Balzer', 'United Team of Germany', '05-06-1938', 26.0, 'Teresa Ciepły', 'Poland', '19-10-1937', 27.0, 'Pam Kilborn', 'Australia', '12-08-1939', 25.0)
# ('80 metres hurdles', '1968', 'Mexico City', 'Maureen Caird', 'Australia', 'No data', None, 'Pam Kilborn', 'Australia', '12-08-1939', 29.0, 'Chi Cheng', 'Taiwan', '15-03-1944', 24.0)
# ('Pentathlon', '1964', 'Tokyo', 'Irina Press', 'Soviet Union', '10-03-1939', 25.0, 'Mary Rand', 'Great Britain', '10-02-1940', 24.0, 'Galina Bystrova', 'Soviet Union', '08-02-1934', 30.0)
# ('Pentathlon', '1968', 'Mexico City', 'Ingrid Becker', 'West Germany', '26-09-1942', 26.0, 'Liese Prokop', 'Austria', '27-03-1941', 27.0, 'Annamária Tóth', 'Hungary', 'No data', None)
# ('Pentathlon', '1972', 'Munich', 'Mary Peters', 'Great Britain', '06-07-1939', 33.0, 'Heide Rosendahl', 'West Germany', '14-02-1947', 25.0, 'Burglinde Pollak', 'East Germany', '10-06-1951', 21.0)
# ('Pentathlon', '1976', 'Montreal', 'Siegrun Siegl', 'East Germany', 'No data', None, 'Christine Laser', 'East Germany', '19-03-1951', 25.0, 'Burglinde Pollak', 'East Germany', '10-06-1951', 25.0)
# ('Pentathlon', '1980', 'Moscow', 'Nadiya Tkachenko', 'Soviet Union', 'No data', None, 'Olga Rukavishnikova', 'Soviet Union', '13-03-1955', 25.0, 'Olga Kuragina', 'Soviet Union', 'No data', None)
# ('10 kilometers race walk', '1992', 'Barcelona', 'Chen Yueling', 'China', 'No data', None, 'Yelena Nikolayeva', 'Unified Team', 'No data', None, 'Li Chunxiu', 'China', 'No data', None)
# ('10 kilometers race walk', '1996', 'Atlanta', 'Yelena Nikolayeva', 'Russia', 'No data', None, 'Elisabetta Perrone', 'Italy', '09-07-1968', 28.0, 'Wang Yan', 'China', 'No data', None)
